# %% [markdown]
# <a href="https://colab.research.google.com/github/mmensahh/Air-Quality-Analysis/blob/main/Print26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ('hello')
# Out:
# hello

# %% [markdown]
# Adding a new hello

# %%
print ('Maxwell Mensah')
# Out:
# Maxwell Mensah
