# %% [markdown]
# <a href="https://colab.research.google.com/github/mmensahh/Air-Quality-Analysis/blob/main/PM2.525.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data Cleaning

# %%
import pandas as pd
df =pd.read_csv('/content/ad_viz_plotval_data.csv')
print(df.head())
# Out:
#          Date  Source   Site ID  POC  Daily Mean PM2.5 Concentration  \
# 0  01/01/2026  AirNow  80010010    3                             8.1
# 1  01/02/2026  AirNow  80010010    3                             4.9
# 2  01/03/2026  AirNow  80010010    3                             8.0
# 3  01/04/2026  AirNow  80010010    3                             2.4
# 4  01/05/2026  AirNow  80010010    3                             5.3
#
#       Units  Daily AQI Value Local Site Name  Daily Obs Count  \
# 0  ug/m3 LC               45    Birch Street                1
# 1  ug/m3 LC               27    Birch Street                1
# 2  ug/m3 LC               44    Birch Street                1
# 3  ug/m3 LC               13    Birch Street                1
# 4  ug/m3 LC               29    Birch Street                1
#
#    Percent Complete  ...  Method Code Method Description  CBSA Code  \
# 0             100.0  ...          NaN                NaN      19740
# ...

# %% [markdown]
# # Dataset Information

# %%
print(df.info()) #information about the datatset

print(df.describe()) #statistics about the data

print(df.isnull().sum()) #this is to check missing data in the
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Date                            46 non-null     object
#  1   Source                          46 non-null     object
#  2   Site ID                         46 non-null     int64
#  3   POC                             46 non-null     int64
#  4   Daily Mean PM2.5 Concentration  46 non-null     float64
#  5   Units                           46 non-null     object
#  6   Daily AQI Value                 46 non-null     int64
#  7   Local Site Name                 46 non-null     object
#  8   Daily Obs Count                 46 non-null     int64
#  9   Percent Complete                46 non-null     float64
#  10  AQS Parameter Code              46 non-null     int64
#  11  AQS Parameter Description       46 non-null     object
# ...
